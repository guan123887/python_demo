# %% [markdown]
# # 这是我的第一个Jupyter程序
#
# ## (1) 写文档，我更好看
# 第2行导入Numpy包，用于计算
# 第4行导入matplotlib包，用于绘图
# 。。。
# ## (2) 输出漂亮的公式（Latex），我更酷
# $ x^3-4x $
#
# ## (3) 测试程序的运行时间，我更方便
# 第14行 测试整个代码块的运行时间

# %%
#导入Numpy包，用于计算
import numpy as np
#导入matplotlib包，用于绘图
import matplotlib.pyplot as plt

#设置随机数种子 
np.random.seed(1)
#随机设置点的x和y坐标

x = np.random.rand(10)
y = np.random.rand(10)
 
colors = np.random.rand(10)
# %timeit area = (40 * np.random.rand(20))**2

# %matplotlib inline

#设置散点图参数
plt.scatter(x,y,s = area, c = colors, alpha = 0.4)
#绘制散点图
plt.show()
# Out:
# 4.38 µs ± 191 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
